# %%
# PHASE-2: DEPLOYMENT
    # In this phase we are going to give the USER for realtime using the created model in phase-1.

# CODE:
    # This is done by importing "pickle"
    # After importing "pickle", The created model is loaded to a new variable "loaded_model"
    # Now the created model is saved in this variable "loaded_model"
    # using "predict" we are going to get the result. The user enters the input value.
    # The predicted value is stored in a variable name "result"
    # When the code is executed we will get the result.
import pickle
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[float(input("Enter Experience: "))]])
result

    # In the orginal data set the starting experience value is 1.1 years.
    # When you enter the input value "Experience" as '0', Still you get a value "array([[26777.3913412]])"
    # This value we get is the 'bias' value
    # In the original data set we do not have any input value for '0' experience but still we get a result.
    # This means that the ORGIN value or BIAS is the starting value.
# Out:
# Enter Experience:  0
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[26777.3913412]])
